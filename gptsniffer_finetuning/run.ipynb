# %%
# !git clone https://github.com/RomanShamailov/codebert_tta_detection.git

# %cd codebert_tta_detection/gptsniffer_finetuning

# %%
# !pip install -r ../requirements.txt

# %%
# !unzip -q dataset.zip

# !ls -l dataset/python/

# %%
import wandb
wandb.login(key="YOUR_KEY")

# %%
# !python fine_tune.py
